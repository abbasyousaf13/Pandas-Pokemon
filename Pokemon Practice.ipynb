# %% [markdown]
# ### Practice

# %%
#Read data with pandas
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/pokemon.csv')

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack         12
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.shape
# Out:
# (800, 13)

# %%
df.notnull().sum()
# Out:
# #             800
# Name          800
# Type 1        800
# Type 2        414
# Total         800
# HP            800
# Attack        788
# Defense       800
# Sp. Atk       800
# Sp. Def       800
# Speed         800
# Generation    800
# Legendary     800
# dtype: int64

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45    49.0       49
# 1      2                Ivysaur    Grass  Poison    405  60    62.0       63
# 2      3               Venusaur    Grass  Poison    525  80     NaN       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80   100.0      123
# 4      4             Charmander     Fire     NaN    309  39     NaN       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50   100.0      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50   160.0      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     NaN       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     NaN       60
# 799  721              Volcanion     Fire   Water    600  80   110.0      120
#
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### LOC and ILOC

# %%
df.loc[(df["Type 1"]=="Fire")]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39     NaN
# 5      5                 Charmeleon   Fire       NaN    405   58    64.0
# 6      6                  Charizard   Fire    Flying    534   78    84.0
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78   130.0
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78   104.0
# 42    37                     Vulpix   Fire       NaN    299   38    41.0
# 43    38                  Ninetales   Fire       NaN    505   73    76.0
# 63    58                  Growlithe   Fire       NaN    350   55     0.0
# 64    59                   Arcanine   Fire       NaN    555   90     0.0
# 83    77                     Ponyta   Fire       NaN    410   50    85.0
# 84    78                   Rapidash   Fire       NaN    500   65   100.0
# 135  126                     Magmar   Fire       NaN    495   65    95.0
# ...

# %%
df.loc[(df["Type 1"]=="Fire") & (df["Attack"]>=90)]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78   130.0
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78   104.0
# 84    78                   Rapidash   Fire       NaN    500   65   100.0
# 135  126                     Magmar   Fire       NaN    495   65    95.0
# 147  136                    Flareon   Fire       NaN    525   65   130.0
# 158  146                    Moltres   Fire    Flying    580   90   100.0
# 263  244                      Entei   Fire       NaN    580  115   115.0
# 270  250                      Ho-oh   Fire    Flying    680  106   130.0
# 278  257                   Blaziken   Fire  Fighting    530   80   120.0
# 279  257      BlazikenMega Blaziken   Fire  Fighting    630   80   160.0
# 353  323                   Camerupt   Fire    Ground    460   70   100.0
# 354  323      CameruptMega Camerupt   Fire    Ground    560   70   120.0
# ...

# %%
df.loc[(df["Type 1"]=="Fire"), ['Name','Speed']]
# Out:
#                           Name  Speed
# 4                   Charmander     65
# 5                   Charmeleon     80
# 6                    Charizard    100
# 7    CharizardMega Charizard X    100
# 8    CharizardMega Charizard Y    100
# 42                      Vulpix     65
# 43                   Ninetales    100
# 63                   Growlithe     60
# 64                    Arcanine     95
# 83                      Ponyta     90
# 84                    Rapidash    105
# 135                     Magmar     93
# 147                    Flareon     65
# 158                    Moltres     90
# 169                  Cyndaquil     65
# 170                    Quilava     80
# 171                 Typhlosion    100
# 236                     Slugma     20
# 237                   Magcargo     30
# 259                      Magby     83
# 263                      Entei    100
# 270                      Ho-oh     90
# 276                    Torchic     45
# 277                  Combusken     55
# ...

# %%
#Pandas takes first argument as row and second as column
df.iloc[0:3]
# Out:
#    #       Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison    318  45    49.0       49       65       65
# 1  2    Ivysaur  Grass  Poison    405  60    62.0       63       80       80
# 2  3   Venusaur  Grass  Poison    525  80     NaN       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
df.iloc[0:5, :-1]
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45    49.0       49
# 1  2                Ivysaur  Grass  Poison    405  60    62.0       63
# 2  3               Venusaur  Grass  Poison    525  80     NaN       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80   100.0      123
# 4  4             Charmander   Fire     NaN    309  39     NaN       43
#
#    Sp. Atk  Sp. Def  Speed  Generation
# 0       65       65     45           1
# 1       80       80     60           1
# 2      100      100     80           1
# 3      122      120     80           1
# 4       60       50     65           1

# %%
df.iloc[[9,28]]
# Out:
#      #      Name  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 9    7  Squirtle   Water    NaN    314  44    48.0       65       50       64
# 28  23     Ekans  Poison    NaN    288  35    60.0       44       40       54
#
#     Speed  Generation  Legendary
# 9      43           1      False
# 28     55           1      False

# %%
df.iloc[[9,28], 2:5]
# Out:
#     Type 1 Type 2  Total
# 9    Water    NaN    314
# 28  Poison    NaN    288

# %% [markdown]
# # One Hot Encoding

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  788.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   77.343909   73.842500   72.820000
# std    208.343798  119.96304   25.534669   34.346611   31.183501   32.722294
# min      1.000000  180.00000    1.000000    0.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      800 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    float64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), float64(1), int64(8), object(3)
# memory usage: 75.9+ KB

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack         12
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df["Attack"].mean()
# Out:
# 77.34390862944163

# %%
#Now this is actually cleaning a data
df.replace(to_replace=np.nan, value=77.34, inplace=True)
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45   49.00       49
# 1      2                Ivysaur    Grass  Poison    405  60   62.00       63
# 2      3               Venusaur    Grass  Poison    525  80   77.34       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80  100.00      123
# 4      4             Charmander     Fire   77.34    309  39   77.34       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50  100.00      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50  160.00      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80   77.34       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80   77.34       60
# 799  721              Volcanion     Fire   Water    600  80  110.00      120
#
# ...

# %%
df.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df["Type 1"].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
df.loc[:,["Type 1"]].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# dtype: int64

# %%
df.sort_values("Defense", ascending=False)
# Out:
#        #                 Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 230  213              Shuckle       Bug    Rock    505   20    10.0      230
# 224  208  SteelixMega Steelix     Steel  Ground    610   75   125.0      230
# 333  306    AggronMega Aggron     Steel   77.34    630   70   140.0      230
# 223  208              Steelix     Steel  Ground    510   75    85.0      200
# 414  377             Regirock      Rock   77.34    580   80   100.0      200
# ..   ...                  ...       ...     ...    ...  ...     ...      ...
# 68    63                 Abra   Psychic   77.34    310   25     0.0       15
# 186  172                Pichu  Electric   77.34    205   20    40.0       15
# 261  242              Blissey    Normal   77.34    540  255    10.0       10
# 488  440              Happiny    Normal   77.34    220  100     5.0        5
# 121  113              Chansey    Normal   77.34    450  250     5.0        5
#
# ...

# %%
df.sort_values(["Defense","Attack"], ascending=[True,False])
# Out:
#        #                 Name    Type 1  Type 2  Total   HP  Attack  Defense  \
# 121  113              Chansey    Normal   77.34    450  250     5.0        5
# 488  440              Happiny    Normal   77.34    220  100     5.0        5
# 261  242              Blissey    Normal   77.34    540  255    10.0       10
# 186  172                Pichu  Electric   77.34    205   20    40.0       15
# 188  174            Igglybuff    Normal   Fairy    210   90    30.0       15
# ..   ...                  ...       ...     ...    ...  ...     ...      ...
# 414  377             Regirock      Rock   77.34    580   80   100.0      200
# 223  208              Steelix     Steel  Ground    510   75    85.0      200
# 333  306    AggronMega Aggron     Steel   77.34    630   70   140.0      230
# 224  208  SteelixMega Steelix     Steel  Ground    610   75   125.0      230
# 230  213              Shuckle       Bug    Rock    505   20    10.0      230
#
# ...

# %% [markdown]
# # Feature Engineering
# ### Add Column

# %%
attack_mean = df["Attack"].mean()

def set_attack(val):
    if val < attack_mean:
        return "Attack Low"
    elif val == attack_mean:
        return "Attack Neutral"
    else:
        return "Attack High"

# %%
df["Attack_high_low"] = df["Attack"].apply(set_attack)
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45   49.00       49
# 1      2                Ivysaur    Grass  Poison    405  60   62.00       63
# 2      3               Venusaur    Grass  Poison    525  80   77.34       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80  100.00      123
# 4      4             Charmander     Fire   77.34    309  39   77.34       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50  100.00      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50  160.00      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80   77.34       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80   77.34       60
# 799  721              Volcanion     Fire   Water    600  80  110.00      120
#
# ...

# %% [markdown]
# ### GroupBy

# %%
df.groupby("Type 1").groups
# Out:
# {'Bug': [13, 14, 15, 16, 17, 18, 19, 51, 52, 53, 54, 132, 136, 137, 179, 180, 181, 182, 208, 219, 220, 228, 229, 230, 231, 232, 288, 289, 290, 291, 292, 307, 308, 314, 315, 316, 342, 343, 446, 447, 457, 458, 459, 460, 461, 462, 463, 520, 600, 601, 602, 603, 604, 605, 618, 619, 649, 650, 656, 657, 677, 678, 693, 697, 698, 717, 732, 733, 734], 'Dark': [212, 213, 233, 246, 247, 248, 284, 285, 326, 327, 392, 393, 478, 512, 549, 568, 569, 620, 621, 631, 632, 685, 686, 690, 691, 694, 695, 696, 756, 757, 793], 'Dragon': [159, 160, 161, 365, 366, 406, 407, 408, 409, 417, 418, 419, 420, 425, 426, 491, 492, 493, 494, 671, 672, 673, 682, 706, 707, 710, 711, 712, 774, 775, 776, 794], 'Electric': [30, 31, 88, 89, 108, 109, 134, 146, 157, 186, 193, 194, 195, 196, 258, 262, 337, 338, 339, 340, 341, 448, 449, 450, 464, 513, 517, 531, 532, 533, 534, 535, 536, 581, 582, 648, 663, 664, 665, 704, 705, 764, 765, 772], 'Fairy': [40, 41, 187, 189, 190, 225, 226, 519, 737, 738, 739, 752, 753, 754, 755, 770,
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45   49.00       49
# 1      2                Ivysaur    Grass  Poison    405  60   62.00       63
# 2      3               Venusaur    Grass  Poison    525  80   77.34       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80  100.00      123
# 4      4             Charmander     Fire   77.34    309  39   77.34       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50  100.00      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50  160.00      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80   77.34       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80   77.34       60
# 799  721              Volcanion     Fire   Water    600  80  110.00      120
#
# ...
